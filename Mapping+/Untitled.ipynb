# %%
import folium
import pandas
map = folium.Map(location = [38.58, -99.09], zoom_start = 6, tiles = "Stamen Terrain")

vol_cd = pandas.read_csv("Volcanoes.txt")
lat = list(vol_cd["LAT"])
lon = vol_cd["LON"]
loc = [lat,lon]
vol_cd
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %%
fg = folium.FeatureGroup(name = "My Map")
for coordinates in loc:
  fg.add_child(folium.Marker(location = loc, popup = "Hi I am a Marker", icon = folium.Icon(color = 'green')))
map.add_child(fg)

map.save("Map1.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python3.8\lib\site-packages\folium\utilities.py in validate_location(location)
#      59         try:
# ---> 60             float(coord)
#      61         except (TypeError, ValueError):
#
# c:\python3.8\lib\site-packages\pandas\core\series.py in wrapper(self)
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#
# TypeError: cannot convert the series to <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b2ec1a5fd0ed> in <module>
#       1 fg = folium.FeatureGroup(name = "My Map")
#       2 for coordinates in loc:
# ...
