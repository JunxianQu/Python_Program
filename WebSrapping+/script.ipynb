# %%
import requests
import pandas
from bs4 import BeautifulSoup

res = []
    r = requests.get("https://www.airbnb.com/s/Big-Bear/homes?flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&adults=2&search_type=pagination&checkin=2021-03-27&refinement_paths%5B%5D=%2Fhomes&date_picker_type=calendar&flexible_trip_lengths%5B%5D=weekend_trip&checkout=2021-03-28&tab_id=home_tab&place_id=ChIJ3yNiUlOxxIARil2OT3SLF5Q&federated_search_session_id=cdc79671-a5f7-4beb-b17f-8a4044ddf3d0&items_offset={}&section_offset=3".format(page), headers={'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36'})
    c = r.content

    soup = BeautifulSoup(c, "html.parser")

    all = soup.find_all("div", {"class":"_gig1e7"})
    hotel_name = []
    price_per_night = []
    reviews = []
    for item in all:
        hotel_name = item.find("a",{"class":"_gjfol0"}).get("aria-label")
        price_per_night = item.find("button",{"class": "_ebe4pze"}).text.split(" ")[0]
        try:
            reviews = item.find(name = "span",attrs = {"aria-label": True}).get("aria-label")

        except:
            reviews = "/"
        df = {}
        df["Hotel Name"] = hotel_name
        df["Price/Night"] = price_per_night
        df["Reviews"] = reviews
        res.append(df)

# %%
final_results = pandas.DataFrame(res)
res

#final_results.to_csv("Output"+"bear"+".csv")
# Out:
# [{'Hotel Name': "Lenny's Lodging Room.",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.45 out of 5; 40 reviews'},
#  {'Hotel Name': 'Cozy cabin for rent.',
#   'Price/Night': '$161',
#   'Reviews': 'Rating 4.53 out of 5; 47 reviews'},
#  {'Hotel Name': 'Large 3 level, 4 bedroom rustic themed cabin',
#   'Price/Night': '$461',
#   'Reviews': 'Rating 4.87 out of 5; 159 reviews'},
#  {'Hotel Name': 'Modern Bungalow Retreat- 5 blocks to SnowPlay',
#   'Price/Night': '$530',
#   'Reviews': 'Rating 4.91 out of 5; 182 reviews'},
#  {'Hotel Name': 'Pet Friendly Resort Cabin ~ Walk to the Village and Lake',
#   'Price/Night': '$310',
#   'Reviews': 'Rating 4.85 out of 5; 93 reviews'},
#  {'Hotel Name': 'babebear Cozy getaway Cabin1#with perfect location',
#   'Price/Night': '$421',
#   'Reviews': '/'},
#  {'Hotel Name': 'Cozy Cabin #10',
#   'Price/Night': '$415',
#   'Reviews': 'Rating 4.70 out of 5; 10 reviews'},
#  {'Hotel Name': 'The National Forest is Your Neighbor- Simple Slope Access',
#   'Price/Night': '$455',
#   'Reviews': 'Rating 4.87 out of 5; 53 reviews'},
#  {'Hotel Name': 'Room #14',
#   'Price/Night': '$217',
#   'Reviews': 'Rating 4.15 out of 5; 33 reviews'},
#  {'Hotel Name': 'The Safe Place',
#   'Price/Night': '$103',
#   'Reviews': 'Rating 4.76 out of 5; 37 reviews'},
#  {'Hotel Name': 'cottage 3 Kit Fox Cozy Retreat',
#   'Price/Night': '$351',
#   'Reviews': 'Rating 4.50 out of 5; 8 reviews'},
#  {'Hotel Name': 'Villa at Timber Haven Lodge',
#   'Price/Night': '$340',
#   'Reviews': 'Rating 4.53 out of 5; 17 reviews'},
#  {'Hotel Name': 'Family Bear Cabin near Village&Lake★Big Yard★',
#   'Price/Night': '$292',
#   'Reviews': '/'},
#  {'Hotel Name': 'Big Bear Lake Home (1 bedroom)',
#   'Price/Night': '$399',
#   'Reviews': '/'},
#  {'Hotel Name': 'Walk to the Village Lakewood Cabins Studio 11',
#   'Price/Night': '$364',
#   'Reviews': 'Rating 4.69 out of 5; 126 reviews'},
#  {'Hotel Name': 'Lil Cabin - FREE Ski/Board Rental! 1BR/1BA/WiFi/Cable TV/Cozy Cabin',
#   'Price/Night': '$388',
#   'Reviews': 'Rating 4.67 out of 5; 13 reviews'},
#  {'Hotel Name': 'Front Row of Snow Summit-Watch slopes from deck!',
#   'Price/Night': '$810',
#   'Reviews': 'Rating 4.83 out of 5; 42 reviews'},
#  {'Hotel Name': 'Deluxe Cabin at Cozy Hollow',
#   'Price/Night': '$350',
#   'Reviews': 'Rating 4.88 out of 5; 16 reviews'},
#  {'Hotel Name': 'Hiner Haven - FREE Ski/Board Rental! - 1BR/1BA/WiFi/Close to Bear Mountain',
#   'Price/Night': '$355',
#   'Reviews': 'Rating 4.38 out of 5; 13 reviews'},
#  {'Hotel Name': 'Small Cabin*Perfect Cabin For Your Mini Getaway!',
#   'Price/Night': '$277',
#   'Reviews': '/'},
#  {'Hotel Name': 'Rustic Chalet w/ Hot Tub! Minutes from Golf & Zoo!',
#   'Price/Night': '$597',
#   'Reviews': 'Rating 4.51 out of 5; 305 reviews'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.51 out of 5; 35 reviews'},
#  {'Hotel Name': 'Cozy Cabin at Timber Haven Lodge',
#   'Price/Night': '$340',
#   'Reviews': 'Rating 4.72 out of 5; 25 reviews'},
#  {'Hotel Name': 'Deluxe Cabin at Cozy Hollow',
#   'Price/Night': '$350',
#   'Reviews': 'Rating 4.88 out of 5; 16 reviews'},
#  {'Hotel Name': 'Nice Room Near Local Attractions! Pets OK',
#   'Price/Night': '$302',
#   'Reviews': 'Rating 4.72 out of 5; 32 reviews'},
#  {'Hotel Name': 'Cabin 23 is one bedroom with king bed',
#   'Price/Night': '$319',
#   'Reviews': 'Rating 4.47 out of 5; 17 reviews'},
#  {'Hotel Name': 'Cabin 15 is stand alone studio with yard',
#   'Price/Night': '$379',
#   'Reviews': 'Rating 4.68 out of 5; 79 reviews'},
#  {'Hotel Name': 'Rustic Cabin #2 w/ Jacuzzi Tub',
#   'Price/Night': '$395',
#   'Reviews': 'Rating 4.55 out of 5; 22 reviews'},
#  {'Hotel Name': '1 Bedroom Cabin with 1 Queen Bed and Fireplace',
#   'Price/Night': '$330',
#   'Reviews': 'Rating 4.43 out of 5; 14 reviews'},
#  {'Hotel Name': 'Great Location-Walk to Snow Summit- Pets ok',
#   'Price/Night': '$628',
#   'Reviews': 'Rating 4.79 out of 5; 600 reviews'},
#  {'Hotel Name': 'Cabin #2',
#   'Price/Night': '$508',
#   'Reviews': 'Rating 4.37 out of 5; 63 reviews'},
#  {'Hotel Name': 'COZY BEAR CABIN- Remodeled! Close to Snow Summit!',
#   'Price/Night': '$501',
#   'Reviews': 'Rating 4.91 out of 5; 23 reviews'},
#  {'Hotel Name': 'Smokey Mountain High',
#   'Price/Night': '$427',
#   'Reviews': 'Rating 4.88 out of 5; 99 reviews'},
#  {'Hotel Name': 'Hiner Haven - FREE Ski/Board Rental! - 1BR/1BA/WiFi/Close to Bear Mountain',
#   'Price/Night': '$355',
#   'Reviews': 'Rating 4.38 out of 5; 13 reviews'},
#  {'Hotel Name': 'GINGERBREAD HOUSE- Pets allowed! Near skiing!',
#   'Price/Night': '$496',
#   'Reviews': 'Rating 4.82 out of 5; 44 reviews'},
#  {'Hotel Name': 'Indulge in a Mountain Getaway at Moonridge Treehouse',
#   'Price/Night': '$1,083',
#   'Reviews': '/'},
#  {'Hotel Name': 'Walk to the Village Lakewood Cabins Studio 11',
#   'Price/Night': '$364',
#   'Reviews': 'Rating 4.69 out of 5; 126 reviews'},
#  {'Hotel Name': 'Large Cabin at Cozy Hollow Sleeps 4',
#   'Price/Night': '$310',
#   'Reviews': 'Rating 4.45 out of 5; 11 reviews'},
#  {'Hotel Name': 'cabin 16  single room sleeps 3',
#   'Price/Night': '$269',
#   'Reviews': 'Rating 3.60 out of 5; 5 reviews'},
#  {'Hotel Name': 'Robinhood’s Retreat** Short walk to SNOWPLAY**',
#   'Price/Night': '$638',
#   'Reviews': 'Rating 4.88 out of 5; 49 reviews'},
#  {'Hotel Name': 'cabin 16  single room sleeps 3',
#   'Price/Night': '$269',
#   'Reviews': 'Rating 3.60 out of 5; 5 reviews'},
#  {'Hotel Name': 'Cottage 7 Perfect Location enjoy Countryside',
#   'Price/Night': '$355',
#   'Reviews': '/'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.40 out of 5; 30 reviews'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.32 out of 5; 28 reviews'},
#  {'Hotel Name': 'Comfortable Cabin at Timber Haven Lodge',
#   'Price/Night': '$340',
#   'Reviews': 'Rating 4.32 out of 5; 19 reviews'},
#  {'Hotel Name': 'Rustic Cabin #5',
#   'Price/Night': '$387',
#   'Reviews': 'Rating 3.80 out of 5; 5 reviews'},
#  {'Hotel Name': 'Studio Cabin Queen - Cozy 12',
#   'Price/Night': '$380',
#   'Reviews': 'Rating 4.57 out of 5; 7 reviews'},
#  {'Hotel Name': 'Homey Cabin Close to Local Attractions!',
#   'Price/Night': '$405',
#   'Reviews': 'Rating 4.73 out of 5; 15 reviews'},
#  {'Hotel Name': 'Big Bear 4 Seasons Four - FREE Ski/Board Rental! - 1BR/1BA/HBO/WiFi/Walk to Lake',
#   'Price/Night': '$323',
#   'Reviews': 'Rating 4.33 out of 5; 6 reviews'},
#  {'Hotel Name': 'Whispering Spruce - FREE Ski/Board Rental! 1BR/1BA/WiFi/Walk to National Forest',
#   'Price/Night': '$438',
#   'Reviews': 'Rating 5.0 out of 5; 20 reviews'},
#  {'Hotel Name': 'GINGERBREAD HOUSE- Pets allowed! Near skiing!',
#   'Price/Night': '$496',
#   'Reviews': 'Rating 4.82 out of 5; 44 reviews'},
#  {'Hotel Name': 'Indulge in a Mountain Getaway at Moonridge Treehouse',
#   'Price/Night': '$1,083',
#   'Reviews': '/'},
#  {'Hotel Name': 'Cabin 19 Single motel room king bed with Balcony',
#   'Price/Night': '$269',
#   'Reviews': 'Rating 4.40 out of 5; 15 reviews'},
#  {'Hotel Name': 'Big Bear Lake Home nxt to Bear Mountain Ski Resort',
#   'Price/Night': '$461',
#   'Reviews': 'Rating 4.70 out of 5; 43 reviews'},
#  {'Hotel Name': 'Alaina’s retreat', 'Price/Night': '$458', 'Reviews': '/'},
#  {'Hotel Name': 'The Getaway - FREE Ski/Board Rental! 1BR/1BA/WiFi',
#   'Price/Night': '$475',
#   'Reviews': 'Rating 4.42 out of 5; 19 reviews'},
#  {'Hotel Name': '2 Room Cabin with Jacuzzi and Full Kitchen',
#   'Price/Night': '$535',
#   'Reviews': 'Rating 4.89 out of 5; 9 reviews'},
#  {'Hotel Name': 'Robinhood’s Retreat** Short walk to SNOWPLAY**',
#   'Price/Night': '$638',
#   'Reviews': 'Rating 4.88 out of 5; 49 reviews'},
#  {'Hotel Name': 'Great Location-Walking distance to Snow Summit',
#   'Price/Night': '$822',
#   'Reviews': 'Rating 4.82 out of 5; 455 reviews'},
#  {'Hotel Name': 'Cabin 4 queen studio with kitchen',
#   'Price/Night': '$279',
#   'Reviews': '/'},
#  {'Hotel Name': 'Bear Hug Hollow- Family Big Bear Experience',
#   'Price/Night': '$741',
#   'Reviews': 'Rating 4.96 out of 5; 25 reviews'},
#  {'Hotel Name': 'Camp Big Bear - FREE Ski/Board Rental! - 3BR/1BA/Game Room/Foosball/WiFi',
#   'Price/Night': '$614',
#   'Reviews': 'Rating 4.57 out of 5; 7 reviews'},
#  {'Hotel Name': '2 Room Cabin with Jacuzzi and Full Kitchen',
#   'Price/Night': '$535',
#   'Reviews': 'Rating 4.89 out of 5; 9 reviews'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.68 out of 5; 19 reviews'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.65 out of 5; 54 reviews'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.56 out of 5; 46 reviews'},
#  {'Hotel Name': 'Cabin with Jetted Spa at Timber Haven Lodge',
#   'Price/Night': '$405',
#   'Reviews': 'Rating 4.14 out of 5; 22 reviews'},
#  {'Hotel Name': 'Cabin in an Awesome Location (ADA Friendly)',
#   'Price/Night': '$462',
#   'Reviews': 'Rating 4.90 out of 5; 21 reviews'},
#  {'Hotel Name': 'Cabin 19 Single motel room king bed with Balcony',
#   'Price/Night': '$269',
#   'Reviews': 'Rating 4.40 out of 5; 15 reviews'},
#  {'Hotel Name': '1 Bedroom Cabin with 1 Queen Bed and Fireplace',
#   'Price/Night': '$330',
#   'Reviews': 'Rating 4.43 out of 5; 14 reviews'},
#  {'Hotel Name': 'cabin 16  single room sleeps 3',
#   'Price/Night': '$269',
#   'Reviews': 'Rating 3.60 out of 5; 5 reviews'},
#  {'Hotel Name': 'Your Own Cabin - Blue Horizon Lodge Cabin 6',
#   'Price/Night': '$444',
#   'Reviews': 'Rating 4.89 out of 5; 9 reviews'},
#  {'Hotel Name': 'Big Bear 4 Seasons Two - FREE Ski/Board Rental! - 1BR/1BA/HBO/WiFi/Walk to Lake',
#   'Price/Night': '$309',
#   'Reviews': 'Rating 3.50 out of 5; 4 reviews'},
#  {'Hotel Name': 'Great Location-Walking distance to Snow Summit',
#   'Price/Night': '$822',
#   'Reviews': 'Rating 4.82 out of 5; 455 reviews'},
#  {'Hotel Name': 'Cozy Ski Retreat in Big Bear Ca w/large deck wi-fi',
#   'Price/Night': '$867',
#   'Reviews': 'Rating 4.57 out of 5; 14 reviews'},
#  {'Hotel Name': 'Heavenly Cabin - FREE Ski/Board Rental! - 2BR/1.5BA/WiFi/Walk to Oktoberfest!',
#   'Price/Night': '$549',
#   'Reviews': 'Rating 4.40 out of 5; 5 reviews'},
#  {'Hotel Name': 'Big Bear Suite Near All w/ Parking! Pets OK!',
#   'Price/Night': '$485',
#   'Reviews': 'Rating 4.67 out of 5; 87 reviews'},
#  {'Hotel Name': 'Lunar Lodge - FREE Ski/Board Rental! 2BR/2BA/Smart TV/WiFi/Forest Views',
#   'Price/Night': '$558',
#   'Reviews': '/'},
#  {'Hotel Name': 'Bearly Rustic - FREE Ski/Board Rental! - 2BR/1BA/WiFi/Nice Back Yard for Snow Play',
#   'Price/Night': '$443',
#   'Reviews': 'Rating 3.90 out of 5; 10 reviews'},
#  {'Hotel Name': '"Reality Escape" Escape from reality in Cozy Cabin',
#   'Price/Night': '$534',
#   'Reviews': 'Rating 4.35 out of 5; 29 reviews'},
#  {'Hotel Name': 'Camp Big Bear - FREE Ski/Board Rental! - 3BR/1BA/Game Room/Foosball/WiFi',
#   'Price/Night': '$614',
#   'Reviews': 'Rating 4.57 out of 5; 7 reviews'},
#  {'Hotel Name': 'Cozy Cabin #3',
#   'Price/Night': '$431',
#   'Reviews': 'Rating 4.88 out of 5; 8 reviews'},
#  {'Hotel Name': 'Teewinot - FREE Ski/Board Rental! 3BR/2BA/WiFi/Breathtaking Views',
#   'Price/Night': '$719',
#   'Reviews': 'Rating 4.86 out of 5; 7 reviews'},
#  {'Hotel Name': 'The Great Escape - FREE Ski/Board Rental! 2BR/ 1BA/ WiFi',
#   'Price/Night': '$446',
#   'Reviews': 'Rating 4.67 out of 5; 3 reviews'},
#  {'Hotel Name': "Lenny's Lodging Room",
#   'Price/Night': '$188',
#   'Reviews': 'Rating 4.43 out of 5; 21 reviews'},
#  {'Hotel Name': 'Cabin 25 King HC studio',
#   'Price/Night': '$339',
#   'Reviews': '/'},
#  {'Hotel Name': 'Cabin 18 Single motel room with King size bed',
#   'Price/Night': '$299',
#   'Reviews': 'Rating 5.0 out of 5; 3 reviews'},
#  {'Hotel Name': 'Cozy Cabin Close to Attractions (ADA Compliant)',
#   'Price/Night': '$462',
#   'Reviews': 'Rating 4.73 out of 5; 11 reviews'},
#  {'Hotel Name': 'Cabin 17 Single  room King bed with fire place',
#   'Price/Night': '$299',
#   'Reviews': 'Rating 4.75 out of 5; 4 reviews'},
#  {'Hotel Name': 'Cabin 2 is two bed rooms  sleep 7',
#   'Price/Night': '$379',
#   'Reviews': 'Rating 4.20 out of 5; 5 reviews'},
#  {'Hotel Name': 'Fireside Spa Suite w/Lake view  Walk To Village',
#   'Price/Night': '$453',
#   'Reviews': 'Rating 4.42 out of 5; 12 reviews'},
#  {'Hotel Name': 'Reese Retreat - FREE Ski/Board Rental! 2BR/1BA/Roku/Prime Video/WiFi/Slope views',
#   'Price/Night': '$603',
#   'Reviews': 'Rating 4.67 out of 5; 3 reviews'},
#  {'Hotel Name': 'Fireside Lodge Chalet Walk To Village',
#   'Price/Night': '$373',
#   'Reviews': 'Rating 4.18 out of 5; 22 reviews'},
#  {'Hotel Name': 'Your Own Cabin - Blue Horizon Lodge Cabin 7',
#   'Price/Night': '$433',
#   'Reviews': 'Rating 4.73 out of 5; 11 reviews'},
#  {'Hotel Name': 'Honey Bear - FREE Ski/Board Rental! - 2BR/1BA/WiFi/Pet friendly/Close to the Lake and Village',
#   'Price/Night': '$480',
#   'Reviews': 'Rating 4.17 out of 5; 6 reviews'},
#  {'Hotel Name': 'Ski Slope Views - FREE Ski/Board Rental! 2BR/1BA/WiFi/Ski Slope Views/Walk to Shuttle',
#   'Price/Night': '$508',
#   'Reviews': 'Rating 3.80 out of 5; 5 reviews'},
#  {'Hotel Name': 'Dream Getaway-Next to Village with Secluded Spa',
#   'Price/Night': '$1,232',
#   'Reviews': 'Rating 4.93 out of 5; 142 reviews'},
#  {'Hotel Name': 'Memory Maker Cabin - FREE Ski/Board Rental! - 2BR/2BA/WiFi/Walk to the Park',
#   'Price/Night': '$482',
#   'Reviews': '/'},
#  {'Hotel Name': '2 Bedroom 2 Bath Lodge with Full Kitchen- Sleeps 8',
#   'Price/Night': '$475',
#   'Reviews': 'Rating 4.86 out of 5; 14 reviews'},
#  {'Hotel Name': '4BR by Village & Ski Resorts! W/Backyard and WiFi',
#   'Price/Night': '$650',
#   'Reviews': 'Rating 4.83 out of 5; 12 reviews'}]

# %%
final_results
# Out:
#                                            Hotel Name Price/Night  \
# 0                               Lenny's Lodging Room.        $188
# 1                                Cozy cabin for rent.        $161
# 2        Large 3 level, 4 bedroom rustic themed cabin        $461
# 3       Modern Bungalow Retreat- 5 blocks to SnowPlay        $530
# 4   Pet Friendly Resort Cabin ~ Walk to the Villag...        $310
# ..                                                ...         ...
# 95  Ski Slope Views - FREE Ski/Board Rental! 2BR/1...        $508
# 96    Dream Getaway-Next to Village with Secluded Spa      $1,232
# 97  Memory Maker Cabin - FREE Ski/Board Rental! - ...        $482
# 98  2 Bedroom 2 Bath Lodge with Full Kitchen- Slee...        $475
# 99  4BR by Village & Ski Resorts! W/Backyard and WiFi        $650
#
#                               Reviews
# 0    Rating 4.45 out of 5; 40 reviews
# 1    Rating 4.53 out of 5; 47 reviews
# 2   Rating 4.87 out of 5; 159 reviews
# 3   Rating 4.91 out of 5; 182 reviews
# 4    Rating 4.85 out of 5; 93 reviews
# ..                                ...
# 95    Rating 3.80 out of 5; 5 reviews
# 96  Rating 4.93 out of 5; 142 reviews
# 97                                  /
# 98   Rating 4.86 out of 5; 14 reviews
# 99   Rating 4.83 out of 5; 12 reviews
#
# [100 rows x 3 columns]
